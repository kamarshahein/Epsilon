# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pylab as plt
covidb = pd.read_csv('/content/loan_data.csv')
covidb
# Out:
#       credit.policy             purpose  ...  pub.rec  not.fully.paid
# 0                 1  debt_consolidation  ...        0               0
# 1                 1         credit_card  ...        0               0
# 2                 1  debt_consolidation  ...        0               0
# 3                 1  debt_consolidation  ...        0               0
# 4                 1         credit_card  ...        0               0
# ...             ...                 ...  ...      ...             ...
# 9573              0           all_other  ...        0               1
# 9574              0           all_other  ...        0               1
# 9575              0  debt_consolidation  ...        0               1
# 9576              0    home_improvement  ...        0               1
# 9577              0  debt_consolidation  ...        0               1
#
# [9578 rows x 14 columns]

# %%
covidb.describe()
# Out:
#        credit.policy     int.rate  ...      pub.rec  not.fully.paid
# count    9578.000000  9578.000000  ...  9578.000000     9578.000000
# mean        0.804970     0.122640  ...     0.062122        0.160054
# std         0.396245     0.026847  ...     0.262126        0.366676
# min         0.000000     0.060000  ...     0.000000        0.000000
# 25%         1.000000     0.103900  ...     0.000000        0.000000
# 50%         1.000000     0.122100  ...     0.000000        0.000000
# 75%         1.000000     0.140700  ...     0.000000        0.000000
# max         1.000000     0.216400  ...     5.000000        1.000000
#
# [8 rows x 13 columns]

# %%
covidb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
covidb.describe(include=['O'])
# Out:
#                    purpose
# count                 9578
# unique                   7
# top     debt_consolidation
# freq                  3957

# %%
covidb.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
total_data=len(covidb)

# %%
from sklearn.model_selection import train_test_split

# %%
covidb.shape
# Out:
# (9578, 14)

# %%
sns.distplot(covidb['int.rate'], kde=True, bins=30, color='m')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df_corr = covidb.corr()
df_corr
# Out:
#                    credit.policy  int.rate  ...   pub.rec  not.fully.paid
# credit.policy           1.000000 -0.294089  ... -0.054243       -0.158119
# int.rate               -0.294089  1.000000  ...  0.098162        0.159552
# installment             0.058770  0.276140  ... -0.032760        0.049955
# log.annual.inc          0.034906  0.056383  ...  0.016506       -0.033439
# dti                    -0.090901  0.220006  ...  0.006209        0.037362
# fico                    0.348319 -0.714821  ... -0.147592       -0.149666
# days.with.cr.line       0.099026 -0.124022  ...  0.071826       -0.029237
# revol.bal              -0.187518  0.092527  ... -0.031010        0.053699
# revol.util             -0.104095  0.464837  ...  0.066717        0.082088
# inq.last.6mths         -0.535511  0.202780  ...  0.072673        0.149452
# delinq.2yrs            -0.076318  0.156079  ...  0.009184        0.008881
# pub.rec                -0.054243  0.098162  ...  1.000000        0.048634
# ...

# %%
sns.heatmap(df_corr, cmap='viridis', linecolor='m', linewidths=3, annot=True)

# %%
covidb.nlargest(5,'installment')
# Out:
#       credit.policy             purpose  ...  pub.rec  not.fully.paid
# 9281              0  debt_consolidation  ...        0               0
# 9288              0      small_business  ...        0               1
# 9309              0  debt_consolidation  ...        0               0
# 9524              0         credit_card  ...        0               0
# 5479              1         credit_card  ...        0               1
#
# [5 rows x 14 columns]

# %%
covidb.nlargest(5,'fico')
# Out:
#       credit.policy             purpose  ...  pub.rec  not.fully.paid
# 1613              1    home_improvement  ...        0               0
# 154               1      small_business  ...        0               0
# 1477              1           all_other  ...        0               0
# 1883              1  debt_consolidation  ...        0               1
# 2476              1      small_business  ...        0               0
#
# [5 rows x 14 columns]

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/loan_data.csv', na_values='829.1', keep_default_na=False)
print(np.count_nonzero(df.isnull().values))
# Out:
# 2

# %%
 import pandas as pd
import pandas as pd
  
gapminder_csv_url ='/content/loan_data.csv'

record = pd.read_csv(gapminder_csv_url)
  
print(record['installment'].unique())
# Out:
# [829.1  228.22 366.86 ... 161.01 257.7  853.43]

# %%
sns.pairplot(covidb)

# %%
covidb.shape
# Out:
# (9578, 14)
